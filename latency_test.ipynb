# %%
# !pip install openai-whisper chromadb rank_bm25 sentence-transformers transformers accelerate bitsandbytes --break-system-packages -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.2/803.2 kB 31.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 65.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 67.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 71.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.1 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-exporter-otlp-proto-common==1.38.0, but you have opentelemetry-exporter-otlp-proto-common 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-proto==1.38.0, but you have opentelemetry-proto 1.42.1 which is incompatible.
# opentelemetry-exporter-otlp-proto-http 1.38.0 requires opentelemetry-sdk~=1.38.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.42.1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-sdk<1.39.0,>=1.36.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.
# opentelemetry-exporter-gcp-logging 1.11.0a0 requires opentelemetry-sdk<1.39.0,>=1.35.0, but you have opentelemetry-sdk 1.42.1 which is incompatible.

# %%
import re
import json
import torch
import numpy as np
import whisper
import chromadb
import time
from sentence_transformers import SentenceTransformer, CrossEncoder
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from rank_bm25 import BM25Okapi

# %%
# !apt-get install -y espeak espeak-data libespeak1 > /dev/null 2>&1
print("espeak installed")
# Out:
# espeak installed

# %%
import subprocess
from IPython.display import Audio, display
import tempfile
import os

# %%
if torch.cuda.is_available():
    print(f"GPU ready: {torch.cuda.get_device_name(0)}")
    print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    print("No GPU")
# Out:
# GPU ready: Tesla T4
# VRAM: 15.6 GB

# %%
from google.colab import drive
drive.mount('/content/drive')

CHUNKS_DIR  = "/content/drive/MyDrive/BM25"
CHROMA_PATH  = "/content/drive/MyDrive/chroma_db"
GT_PATH = "/content/drive/MyDrive/ground_truth.json"
OUT_PATH = "/content/drive/MyDrive/evaluation_results.json"
# Out:
# Mounted at /content/drive

# %%
def timer(label, timings_dict):
    class Timer:
        def __enter__(self):
            self.start = time.time()
            return self
        def __exit__(self, *args):
            timings_dict[label] = time.time() - self.start
    return Timer()

def print_timings(timings):
    print(f"\n")
    print("  Latency breakdown")
    print(f"\n")
    total = sum(timings.values())
    for stage, t in timings.items():
        bar   = "█" * int((t / total) * 30) if total > 0 else ""
        print(f"  {stage:<25} {t:.3f}s  {bar}")
    print(f"  {'TOTAL':<25} {total:.3f}s")

# %%
#embedder
embedder = SentenceTransformer("all-mpnet-base-v2")
print("Embedder ready")

#chromaDB
client     = chromadb.PersistentClient(path=CHROMA_PATH)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/11.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embedder ready

# %%
cross_encoder = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
print("Cross-encoder ready")
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/1.33k [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Cross-encoder ready

# %%
MODEL_ID   = "mistralai/Mistral-7B-Instruct-v0.2"
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

print("Loading tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID)

print("Loading Mistral (first time takes a few minutes)...")
model_llm = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    quantization_config=bnb_config,
    device_map="auto",
)
print(f"Mistral loaded on: {next(model_llm.parameters()).device}")
# Out:
# Loading tokenizer...
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.10k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# Loading Mistral (first time takes a few minutes)...
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 3 files:   0%|          | 0/3 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:213: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Mistral loaded on: cuda:0

# %% [markdown]
# modello small

# %%
def rerank(query, candidates):
    pairs  = [(query, c["text"]) for c in candidates]
    scores = cross_encoder.predict(pairs)
    for i, score in enumerate(scores):
        candidates[i]["rerank_score"] = float(score)
    return sorted(candidates, key=lambda x: x["rerank_score"], reverse=True)

# %%
model_asr = whisper.load_model("small", device="cuda")
print("Whisper ready")
# Out:
# 100%|████████████████████████████████████████| 461M/461M [00:03<00:00, 121MiB/s]
# Whisper ready

# %%
def build_prompt(query, chunks):
    context_parts = []
    for i, chunk in enumerate(chunks):
        page = chunk["metadata"].get("page_number", "?")
        context_parts.append(f"[Chunk {i+1} | Page {page}]\n{chunk['text']}")
    context = "\n\n".join(context_parts)
    return f"""You are an automotive diagnostic assistant. Answer the technician's question using ONLY the manual excerpts provided below.

Rules:
- Only use information from the provided excerpts
- Always cite the page number in square brackets e.g. [Page 47]
- If the answer is not in the excerpts, say "I could not find this in the manual"
- Be concise and precise

Manual excerpts:
{context}

Technician's question: {query}

Answer:"""

# %%
def retrieve_all(query, top_k=5, timings=None, prefix=""):
    """
    Runs BM25, dense, and RRF fusion separately.
    Returns all three result sets for inspection.
    """
    if collection is None or bm25 is None:
        print("ERROR: no vehicle loaded — call check_vehicle() first")
        return None

    # BM25
    with timer (f"{prefix}BM25",  timings or {}):
      tokens   = query.lower().split()
      bm25_scores = bm25.get_scores(tokens)
      top_idx  = np.argsort(bm25_scores)[::-1][:top_k * 2]
      bm25_results = [
        {"text": chunks[i]["text"], "metadata": chunks[i]["metadata"], "score": float(bm25_scores[i])}
        for i in top_idx
      ]

    # Dense
    with timer (f"{prefix}dense", timings or {}):
      qvec    = embedder.encode([query])[0].tolist()
      results = collection.query(
          query_embeddings=[qvec],
          n_results=top_k * 2,
          include=["documents", "metadatas", "distances"]
      )
      dense_results = [
        {"text": d, "metadata": m, "score": 1 - s}
        for d, m, s in zip(
            results["documents"][0],
            results["metadatas"][0],
            results["distances"][0]
        )
      ]

    # RRF fusion
    with timer (f"{prefix}rrf", timings or {}):
      rrf_scores = {}
      for rank, r in enumerate(dense_results):
          key = r["text"][:50]
          rrf_scores[key] = rrf_scores.get(key, {"score": 0, "data": r})
          rrf_scores[key]["score"] += 0.5 * (1 / (rank + 1))
      for rank, r in enumerate(bm25_results):
          key = r["text"][:50]
          if key not in rrf_scores:
              rrf_scores[key] = {"score": 0, "data": r}
          rrf_scores[key]["score"] += 0.5 * (1 / (rank + 1))
      rrf_results = [r["data"] for r in sorted(
          rrf_scores.values(), key=lambda x: x["score"], reverse=True
      )][:top_k]

    return {
        "bm25":   bm25_results[:top_k],
        "dense":  dense_results[:top_k],
        "rrf":    rrf_results,
    }

# %%
def generate(query, chunks_for_generation, max_new_tokens=300):
    """
    Takes a query and a list of chunks,
    builds prompt, runs Mistral, returns answer string.
    """
    if not chunks_for_generation:
        return "No relevant chunks found — cannot generate answer."

    prompt    = build_prompt(query, chunks_for_generation)
    inputs    = tokenizer(prompt, return_tensors="pt").to(model_llm.device)
    input_len = inputs["input_ids"].shape[1]

    with torch.no_grad():
        outputs = model_llm.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            do_sample=False,
            temperature=1.0,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
        )

    new_tokens = outputs[0][input_len:]
    answer     = tokenizer.decode(new_tokens, skip_special_tokens=True)
    if "Technician's question:" in answer:
        answer = answer[:answer.index("Technician's question:")].strip()
    return answer.strip()

# %% [markdown]
# aggiungere ultime modifiche a synonym map

# %%
SYNONYM_MAP = {
    # --- COMPONENTS ---
    "gearbox":              ["transmission", "dualogic", "gearbox fault light"],
    "gear box":             ["transmission", "dualogic", "gearbox fault light"],
    "gear with exclamation":["transmission", "dualogic", "gearbox fault light"],
    "parking brake":        ["handbrake"],
    "boot":                 ["luggage compartment"],
    "trunk":                ["luggage compartment"],
    "blinker":              ["direction indicator"],
    "turn signal":          ["direction indicator"],
    "ac":                   ["air conditioning", "climate control"],
    "air con":              ["air conditioning", "climate control"],
    "aircon":               ["air conditioning", "climate control"],
    "rev counter":          ["tachometer"],
    "rpm gauge":            ["tachometer"],
    "shift":                ["gearbox"],

    # --- SYMPTOMS ---
    "won't start":          ["engine starting failure"],
    "wont start":           ["engine starting failure"],
    "doesn't start":        ["engine starting failure"],
    "doesnt start":         ["engine starting failure"],
    "not starting":         ["engine starting failure"],
    "can't start":          ["engine starting failure"],
    "cant start":           ["engine starting failure"],
    "overheating":          ["engine coolant temperature"],
    "getting hot":          ["engine coolant temperature"],
    "too hot":              ["engine coolant temperature"],
    "running hot":          ["engine coolant temperature"],
    "making noise":         ["abnormal noise"],
    "strange noise":        ["abnormal noise"],
    "weird noise":          ["abnormal noise"],
    "pulling to one side":  ["steering"],
    "drifting":             ["steering"],
    "turning":             ["steering"],
    "drinking fuel":        ["fuel consumption"],
    "using too much fuel":  ["fuel consumption"],
    "high fuel use":        ["fuel consumption"],
    "stalling":             ["engine stalling", "ignition malfunction", "Fuel cut-off"],
    "cutting out":          ["engine stalling", "ignition malfunction", "Fuel cut-off"],
    "dying":                ["engine stalling", "ignition malfunction", "Fuel cut-off"],
    "squeaking":            ["vibration", "noise", "pulsating"],
    "squealing":            ["vibration", "noise", "pulsating"],
    "shaking":              ["vibration", "noise", "pulsating"],
    "shuddering":           ["vibration", "noise", "pulsating"],
    "vibrating":            ["vibration", "noise", "pulsating"],
    "flat tyre":            ["tyre pressure", "tyre"],
    "puncture":             ["tyre pressure", "tyre"],
    "blowout":              ["tyre pressure", "tyre"],
    "tyres wearing":        ["tyre pressure", "tyre"],
    "wearing unevenly":     ["tyre pressure", "tyre"],
    "smoke":                ["engine smoke", "overheating", "cooling", "emergency"],
    "smoking":              ["engine smoke", "overheating", "cooling", "emergency"],
    "grinding":             ["brake pad wear"],
    "smell":                ["leak", "overheating"],
    "not working":          ["replacing", "replacement"],
    "leak":                 ["check fluid"],

    # --- ICON VISUAL DESCRIPTIONS ---
    "spanner":                                   ["scheduled servicing"],
    "wrench symbol":                             ["scheduled servicing"],
    "tool icon":                                 ["scheduled servicing"],
    "handbrake warning":                         ["handbrake"],
    "oil can":                                   ["insufficient engine oil pressure light"],
    "oil symbol":                                ["insufficient engine oil pressure light"],
    "oil drop":                                  ["insufficient engine oil pressure light"],
    "oil light":                                 ["insufficient engine oil pressure light"],
    "oil can with waves":                        ["engine oil minimum level light"],
    "oil drop over water":                       ["engine oil minimum level light"],
    "oil symbol with waves":                     ["engine oil minimum level light"],
    "exclamation mark in triangle":              ["general failure warning light"],
    "warning triangle":                          ["general failure warning light"],
    "triangle with exclamation":                 ["general failure warning light"],
    "exclamation mark in circle":                ["low brake fluid handbrake engaged light"],
    "circle with exclamation":                   ["low brake fluid handbrake engaged light"],
    "round exclamation":                         ["low brake fluid handbrake engaged light"],
    "seatbelt":                                  ["seat belts not fastened light"],
    "belt symbol":                               ["seat belts not fastened light"],
    "car with lock":                             ["fiat code system failure light"],
    "car with padlock":                          ["fiat code system failure light"],
    "car with a padlock symbol":                 ["fiat code system failure light"],
    "snowflake":                                 ["possible ice on road light"],
    "ice symbol":                                ["possible ice on road light"],
    "ice icon":                                  ["possible ice on road light"],
    "abs circle exclamation":                    ["EBD failure light"],
    "steering wheel exclamation":                ["dualdrive electric power steering system failure"],
    "wheel with exclamation":                    ["dualdrive electric power steering system failure"],
    "car going uphill":                          ["hill holder system failure"],
    "car in circle going up":                    ["hill holder system failure"],
    "filter with smoke":                         ["DPF cleaning particulate trap"],
    "particles blowing through":                 ["DPF cleaning particulate trap"],
    "air blowing through box":                   ["DPF cleaning particulate trap"],
    "p with radar waves":                        ["parking sensor failure light"],
    "p with signal waves":                       ["parking sensor failure light"],
    "huge p with wifi":                          ["parking sensor failure light"],
    "fuel pump with drops":                      ["water in diesel filter"],
    "gas pump with liquid dripping":             ["water in diesel filter"],
    "light bulb exclamation":                    ["external lights failure"],
    "circle with dots":                          ["brake pad wear"],
    "horseshoe with exclamation":                ["tyre pressure warning itpms"],
    "horseshoe shape with an exclamation mark":  ["tyre pressure warning itpms"],
    "flat tire light":                           ["tyre pressure warning itpms"],
    "bowl with exclamation":                     ["tyre pressure warning itpms"],
    "person with circle x":                      ["passenger side airbag deactivated"],
    "airbag light two":                          ["passenger side airbag deactivated"],
    "passenger airbag":                          ["passenger side airbag deactivated"],
    "light with vertical line":                  ["rear fog light"],
    "light lines left vertical":                 ["front fog lights"],
    "speedometer icon":                          ["cruise control"],
    "dial with needle":                          ["cruise control"],
    "two headlights":                            ["side lights dipped beam headlights"],
    "headlight going left":                      ["main beam headlights"],
    "high beam":                                 ["main beam headlights"],
    "lpg failure":                               ["lpg system failure"],
    "fuel pump lpg":                             ["lpg system failure"],
    "cng":                                       ["methane system failure"],
    "methane":                                   ["methane system failure"],
    "check engine light":                        ["injection eobd system failure"],
    "engine light":                              ["injection eobd system failure"],
    "engine warning":                            ["injection eobd system failure"],
    "engine shaped light":                       ["injection eobd system failure"],
    "abs light":                                 ["abs failure light"],
    "abs written":                               ["abs failure light"],
    "airbag light":                              ["air bag failure"],
    "person with circle":                        ["air bag failure"],
    "car with skid marks":                       ["esc system failure"],
    "blue headlight":                            ["main beam headlights"],
}

# %%
def normalize_apostrophes(text):
    return text.replace('\u2019', "'").replace('\u2018', "'")

def clean_query(text):
    text    = normalize_apostrophes(text.lower().strip())
    fillers = ["um", "uh", "like", "you know", "i mean", "so", "basically"]
    for f in fillers:
        text = re.sub(rf'\b{f}\b', '', text)
    return re.sub(r'\s+', ' ', text).strip()

def enrich_query(query):
    cleaned    = clean_query(query)
    expansions = []
    matched    = []
    for colloquial, technical_terms in SYNONYM_MAP.items():
        if normalize_apostrophes(colloquial) in cleaned:
            expansions.extend(technical_terms)
            matched.append(colloquial)
    if expansions:
        seen     = set()
        unique   = [x for x in expansions if not (x in seen or seen.add(x))]
        enriched = cleaned + " " + " ".join(unique)
    else:
        enriched = cleaned
    return enriched, matched

# %%
current_vehicle = None
chunks          = []
collection      = None
bm25            = None

def load_vehicle(vehicle):
    global current_vehicle, chunks, collection, bm25

    chunks_path = f"{CHUNKS_DIR}/{vehicle}.json"
    with open(chunks_path, encoding="utf-8") as f:
        chunks = json.load(f)
    print(f"Loaded {len(chunks)} chunks")

    tokenized = [c["text"].lower().split() for c in chunks]
    bm25      = BM25Okapi(tokenized)
    print(f"BM25 ready — {len(tokenized)} documents")

    collection = client.get_collection(vehicle)
    print(f"ChromaDB loaded — {collection.count()} chunks")

    current_vehicle = vehicle
    print(f"Vehicle set to: {current_vehicle}")

def check_vehicle():
    global current_vehicle
    if current_vehicle is not None:
        return True
    vehicle = input("Please specify your vehicle (e.g. 'punto'): ").strip()
    if vehicle:
        load_vehicle(vehicle)
        return True
    print("No vehicle specified — cannot proceed.")
    return False

# %%
def speak(text, speed=150, save_path=None):
    path = save_path or "/content/drive/MyDrive/thesis/result.wav"

    subprocess.run([
        "espeak",
        "-v", "en",
        "-s", str(speed),
        "-w", path,
        text
    ], check=True)

    display(Audio(path, autoplay=True))
    return path

# %%
def print_results(label, results_dict, show_scores=True):
    """
    Standardised printing for all retrieval stages.
    Pass label (e.g. "RAW QUERY") and results dict from retrieve().
    """
    print(f"\n")
    print(f"  {label}")
    print(f"\n")

    for stage in ["bm25", "dense", "rrf", "reranked"]:
        if stage not in results_dict:
            continue
        print(f"\n--- {stage.upper()} ---")
        for i, r in enumerate(results_dict[stage]):
            page  = r["metadata"].get("page_number", "?")
            score = r.get("rerank_score", r.get("score", 0))
            score_str = f"| score {score:.3f} " if show_scores else ""
            print(f"  [{i+1}] p{page} {score_str}| {r['text'][:100]}...")

def print_answer(label, answer):
    print(f"\n")
    print(f"  ANSWER — {label}")
    print(f"\n")
    print(answer)

# %%
def pipeline(
    query         = None,
    audio_path    = None,
    use_enrichment = True,    # False → skip enrichment, use raw query only
    generate_answers = True,  # False → skip generation, show retrieval only
    speak_answer  = True,
    top_k         = 5,
    measure_latency  = True,
):
    """
    Full pipeline with experimental flags:
      use_enrichment=False   → retrieval on raw query only (no SYNONYM_MAP)
      generate_answers=False → skip Mistral, useful for fast retrieval testing
      speak_answer=False     → skip TTS
    """
    if not check_vehicle():
        return

    timings = {}

    # Input
    if audio_path is not None:
        with timer("asr", timings):
          result    = model_asr.transcribe(
            audio_path,
            language="en",
            initial_prompt="Automotive diagnostic report. Car problems, warning lights, engine issues.",
            fp16=True,
          )
        raw_query = result["text"].strip()
        print(f"Transcript:  {raw_query}")
    elif query is not None:
        raw_query = query
    else:
        print("ERROR: provide either query= or audio_path=")
        return

    # Query analysis
    with timer("query_analysis", timings):
      enriched, matched = enrich_query(raw_query)

    print(f"\nORIGINAL:  {raw_query}")
    if use_enrichment and matched:
        print(f"ENRICHED:  {enriched}")
        print(f"TRIGGERED: {matched}")
    elif use_enrichment and not matched:
        print("ENRICHED:  (no enrichment applied — query already technical)")
    else:
        print("ENRICHED:  (enrichment disabled)")

    # Retrieval

    with timer("retrieval_raw", timings):
        raw_results = retrieve_all(raw_query, top_k=top_k, timings=timings, prefix="raw_")
        raw_reranked            = rerank(raw_query, raw_results["rrf"])[:top_k]
        raw_results["reranked"] = raw_reranked
    print_results("RETRIEVAL — RAW QUERY", raw_results)

    if use_enrichment and matched:
        with timer("retrieval_enriched", timings):
            enriched_results = retrieve_all(enriched, top_k=top_k, timings=timings, prefix="enriched_")
            enriched_reranked            = rerank(enriched, enriched_results["rrf"])[:top_k]
            enriched_results["reranked"] = enriched_reranked
        print_results("RETRIEVAL — ENRICHED QUERY", enriched_results)
    else:
        enriched_results = raw_results


    # Generation
    if generate_answers:
        with timer("generation_rrf_raw", timings):
          # Condition 1: RRF only, raw query
          ans_rrf_raw = generate(raw_query, raw_results["rrf"])
        print_answer("RRF | raw query", ans_rrf_raw)

        # Condition 2: Reranked, raw query
        with timer("generation_ranked_raw", timings):
          ans_reranked_raw = generate(raw_query, raw_results["reranked"])
        print_answer("Reranked | raw query", ans_reranked_raw)

        if use_enrichment and matched:
            with timer("generation_rrf_enriched", timings):
              # Condition 3: RRF only, enriched query
              ans_rrf_enriched = generate(enriched, enriched_results["rrf"])
            print_answer("RRF | enriched query", ans_rrf_enriched)

            with timer("generation_ranked_enriched", timings):
              # Condition 4: Reranked, enriched query
              ans_reranked_enriched = generate(enriched, enriched_results["reranked"])
            print_answer("Reranked | enriched query", ans_reranked_enriched)

            # TTS on best answer (reranked + enriched)
            if speak_answer:
                print("\n Speaking best answer (reranked + enriched)...")
                speak(ans_reranked_enriched)
        else:
            if speak_answer:
                print("\n Speaking best answer (reranked)...")
                speak(ans_reranked_raw)
    else:
        print("\n(generation skipped — set generate_answers=True to run Mistral)")

    if measure_latency:
        print_timings(timings)

    return timings

# %% [markdown]
# Latency test

# %%
def run_evaluation(
    json_path,
    output_path,
    top_k=5,
):
    if not check_vehicle():
        return

    with open(json_path, encoding="utf-8") as f:
        dataset = json.load(f)

    if os.path.exists(output_path):
        with open(output_path, encoding="utf-8") as f:
            results = json.load(f)
    else:
        results = {}

    total = len(dataset)

    for idx, entry in enumerate(dataset):
        query_key = f"query_{idx + 1}"

        if query_key in results:
            continue

        user_input = entry["user_input"]

        t0 = time.perf_counter()
        enriched, triggered = enrich_query(user_input)
        enrich_latency = time.perf_counter() - t0

        # RAW pipeline

        t0 = time.perf_counter()
        raw_rrf = retrieve_all(user_input, top_k=top_k)
        raw_retrieval_latency = time.perf_counter() - t0

        t0 = time.perf_counter()
        raw_ans = generate(user_input, raw_rrf["rrf"])
        raw_generation_latency = time.perf_counter() - t0

        raw_pages = [
            r["metadata"].get("page_number")
            for r in raw_rrf["rrf"]
        ]

        # ENRICHED pipeline

        t0 = time.perf_counter()
        enr_rrf = retrieve_all(enriched, top_k=top_k)
        enr_retrieval_latency = time.perf_counter() - t0

        t0 = time.perf_counter()
        enr_ans = generate(enriched, enr_rrf["rrf"])
        enr_generation_latency = time.perf_counter() - t0

        enr_pages = [
            r["metadata"].get("page_number")
            for r in enr_rrf["rrf"]
        ]

        # RERANKED pipeline

        t0 = time.perf_counter()
        enr_rrf_wide = retrieve_all(enriched, top_k=top_k * 2)
        reranked_chunks = rerank(
            enriched,
            enr_rrf_wide["rrf"]
        )[:top_k]
        rerank_latency = time.perf_counter() - t0

        t0 = time.perf_counter()
        rer_ans = generate(enriched, reranked_chunks)
        rer_generation_latency = time.perf_counter() - t0

        rer_pages = [
            r["metadata"].get("page_number")
            for r in reranked_chunks
        ]

        rer_scores = [
            round(r.get("rerank_score", 0), 3)
            for r in reranked_chunks
        ]

        results[query_key] = {
            "user_input": user_input,
            "category": entry.get("category", ""),
            "relevant_pages": entry.get("relevant_pages", []),

            "enriched_query": enriched,
            "triggered": triggered,

            "latency": {
                "query_enrichment": enrich_latency,

                "raw_retrieval": raw_retrieval_latency,
                "raw_generation": raw_generation_latency,

                "enriched_retrieval": enr_retrieval_latency,
                "enriched_generation": enr_generation_latency,

                "reranking": rerank_latency,
                "reranked_generation": rer_generation_latency,
            },

            "raw": {
                "retrieved_pages": raw_pages,
                "answer": raw_ans,
            },

            "enriched": {
                "retrieved_pages": enr_pages,
                "answer": enr_ans,
            },

            "reranked": {
                "retrieved_pages": rer_pages,
                "rerank_scores": rer_scores,
                "answer": rer_ans,
            },
        }

        # Save after every query
        with open(output_path, "w", encoding="utf-8") as f:
            json.dump(results, f, indent=2, ensure_ascii=False)

    return results

# %%
run_evaluation(
    json_path="/content/drive/MyDrive/ground_truth.json",
    output_path="/content/drive/MyDrive/latency_results.json",
    top_k=5
)
# Out:
# Please specify your vehicle (e.g. 'punto'): punto
# Loaded 959 chunks
# BM25 ready — 959 documents
# ChromaDB loaded — 959 chunks
# Vehicle set to: punto
# /usr/local/lib/python3.12/dist-packages/bitsandbytes/backends/cuda/ops.py:468: FutureWarning: _check_is_size will be removed in a future PyTorch release along with guard_size_oblivious.     Use _check(i >= 0) instead.
#   torch._check_is_size(blocksize)
# {'query_1': {'user_input': "there's a warning triangle on the dashboard",
#   'category': 'icon',
#   'relevant_pages': [52],
#   'enriched_query': "there's a warning triangle on the dashboard general failure warning light",
#   'triggered': ['warning triangle'],
#   'latency': {'query_enrichment': 0.000532770000063465,
#    'raw_retrieval': 0.9825235260000227,
#    'raw_generation': 18.68386719900036,
#    'enriched_retrieval': 0.056484526000076585,
#    'enriched_generation': 8.378674979999687,
#    'reranking': 0.11271421299989015,
#    'reranked_generation': 11.80535259699991},
#   'raw': {'retrieved_pages': [78, 77, 46, 99, 19],
#    'answer': 'Check the coolant level [Page 46] or access the dashboard fuse box [Page 99] as described in the manual. If the warning light is due to an issue with the passenger airbag, do not apply stickers or other objects on the steering wheel, dashboard, roof or seats [Page 77-78].'},
#   'enriched': {'retrieved_pages': [52, 19, 62, 53, 78],
#    'answer': 'According to the manual [Chunk 1, Page 52] and [Chunk 4, Page 53], the general failure warning light comes on when there is a system failure. Therefore, the warning triangle on the dashboard indicates a system failure. The manual advises to go to a Fiat Dealership to have the system checked. [Page 52, 53]'},
#   'reranked': {'retrieved_pages': [52, 53, 41, 52, 50],
#    'rerank_scores': [4.246, 4.025, 1.802, 1.583, 1.218],
#    'answer': 'According to the manual excerpts provided, the general failure warning light comes on in various circumstances such as limit speed exceeded, fuel cut-off activated, airbag failure, and parking sensor failure [Page 52, 53]. If the warning light is flashing while driving, it may indicate a system failure that requires checking at a Fiat Dealership [Page 53]. Therefore, the technician should go to a Fiat Dealership to have the system checked. [Page 52, 53]'}},
#  'query_2': {'user_input': 'I see an oil can light on my dashboard',
#   'category': 'icon',
#   'relevant_pages': [44, 45],
#   'enriched_query': 'i see an oil can light on my dashboard insufficient engine oil pressure light',
#   'triggered': ['oil can'],
#   'latency': {'query_enrichment': 0.0001216000000567874,
#    'raw_retrieval': 0.019026520999886998,
#    'raw_generation': 15.617517548999786,
#    'enriched_retrieval': 0.02391899799977182,
#    'enriched_generation': 7.643510257999878,
#    'reranking': 0.03361252400009107,
#    'reranked_generation': 4.5704290409998976},
#   'raw': {'retrieved_pages': [43, 101, 44, 45, 173],
#    'answer': 'According to the manual [Page 43], the engine oil minimum level light comes on when the engine oil level falls below the minimum recommended value. Restore the correct engine oil level. If the warning light comes on while driving, stop the engine immediately and contact a Fiat Dealership [Page 47]. If the warning light flashes and the engine is a MultiJet version with DPF, the oil may be degraded and needs to be changed [Page 45]. To access the dashboard fuse box and check the fuses, refer to [Page 172].\n\nCitation:\n[Page 43, 44, 45, 172]'},
#   'enriched': {'retrieved_pages': [44, 44, 43, 45, 52],
#    'answer': 'According to the manual [Page 44], if the insufficient engine oil pressure warning light comes on while the engine is running, it indicates a constant issue with the engine oil pressure. You should stop the engine immediately and contact a Fiat Dealership [Page 47].'},
#   'reranked': {'retrieved_pages': [44, 44, 52, 43, 45],
#    'rerank_scores': [5.438, 5.058, 1.311, 0.714, 0.147],
#    'answer': 'According to the manual [Page  47], if the insufficient engine oil pressure light comes on while driving, stop the engine immediately and contact a Fiat Dealership.'}},
#  'query_3': {'user_input': 'oil can with waves underneath on my dashboard',
#   'category': 'icon',
#   'relevant_pages': [43],
#   'enriched_query': 'oil can with waves underneath on my dashboard insufficient engine oil pressure light engine oil minimum level light',
#   'triggered': ['oil can', 'oil can with waves'],
#   'latency': {'query_enrichment': 0.00010992799980158452,
#    'raw_retrieval': 0.024969378999685432,
#    'raw_generation': 30.350664873999904,
#    'enriched_retrieval': 0.033682605999729276,
#    'enriched_generation': 24.960413320000043,
#    'reranking': 0.038741247999951156,
#    'reranked_generation': 16.56252543799974},
#   'raw': {'retrieved_pages': [44, 101, 45, 152, 77],
#    'answer': 'I could not find this in the manual.'},
#   'enriched': {'retrieved_pages': [43, 44, 44, 45, 127],
#    'answer': '[Based on Chunk 1 and Chunk 4, Page 43 and 44]\n\nThe insufficient engine oil pressure light and engine oil minimum level light are related to the engine oil level. If the oil level is below the minimum recommended value, both lights may come on. However, if the lights are flashing, it could indicate degraded engine oil, as described in Chunk 4 on Page 44. In this case, the oil should be changed.\n\nTo check the oil level, follow the instructions in Chunk 5 on Page 127. If the oil level is low, add oil via the filler fitting until the MAX mark is reached. If the oil is degraded, it should be changed.\n\nI could not find specific information in the manual about the waves underneath the oil can symbol on the dashboard.'},
#   'reranked': {'retrieved_pages': [43, 44, 44, 45, 45],
#    'rerank_scores': [1.425, 1.04, 0.926, -4.865, -5.478],
#    'answer': 'According to the manual [Chunk 1, Page 43] and [Chunk 2, Page 44], the insufficient engine oil pressure light and engine oil minimum level light are related to the engine oil level. If the warning light comes on while driving, as described in the question, and does not go off after starting the engine, it is recommended to stop the engine immediately and contact a Fiat Dealership [Chunk 3, Page 44]. Therefore, the waves underneath the dashboard could be an indication of insufficient engine oil pressure or a low engine oil level.'}},
#  'query_4': {'user_input': "there's a horseshoe shape with an exclamation mark on the dashboard",
#   'category': 'icon',
#   'relevant_pages': [55, 62],
#   'enriched_query': "there's a horseshoe shape with an exclamation mark on the dashboard tyre pressure warning itpms",
#   'triggered': ['horseshoe shape with an exclamation mark'],
#   'latency': {'query_enrichment': 0.00012913699993077898,
#    'raw_retrieval': 0.026745095000023866,
#    'raw_generation': 15.446898014999988,
#    'enriched_retrieval': 0.027513589000136562,
#    'enriched_generation': 17.865452621999793,
#    'reranking': 0.03763968100020065,
#    'reranked_generation': 15.5840142750003},
#   'raw': {'retrieved_pages': [173, 77, 99, 169, 163],
#    'answer': 'The horseshoe shape with an exclamation mark on the dashboard is likely a warning symbol for the airbag system [Page 163]. To diagnose and possibly reset this warning, refer to the relevant section in the manual. Access the dashboard fuse box by opening the glove compartment [Page 172] and removing the cover [Page 99]. The fuse related to the airbag system may be found in the fuse box diagram [Page 173]. However, be cautious not to apply stickers or other objects on the dashboard, especially in the passenger side airbag area [Page 77], as this could interfere with the airbag deployment and cause injury.'},
#   'enriched': {'retrieved_pages': [55, 61, 62, 52, 61],
#    'answer': 'According to the manual [Chunk 2, Page 61], the iTPMS system warns the driver if one or more tyres are flat. The symbol on the dashboard indicates a tyre pressure issue. Therefore, it is recommended to check the tyre pressure on all four tyres as soon as possible [Chunk 3, Page 63]. If only one tyre is flat, the system may indicate its position [Chunk 2, Page 61]. However, the driver is still responsible for monthly tyre pressure checks and the iTPMS system does not replace routine maintenance or safety systems [Chunk 3, Page 63-64]. If the issue persists after adjusting the tyre pressure, contact a Fiat Dealership [Chunk 4, Page 62].'},
#   'reranked': {'retrieved_pages': [55, 61, 52, 62, 62],
#    'rerank_scores': [-0.688, -1.143, -2.622, -2.971, -3.374],
#    'answer': "According to the manual [Chunk 2, Page 61], the horseshoe shape with an exclamation mark on the dashboard is the iTPMS warning light. It indicates that one or more tyres have lower pressure than the recommended value. The driver is advised to check the pressure on all four tyres [Chunk 1, Page 55]. This warning does not relieve the driver from the monthly tyre pressure checks [Chunk  4, Page  62]. The iTPMS system cannot indicate sudden tyre pressure drops [Chunk 5, Page 62].\n\n[Source: Fiat Panda Owner's Manual]"}},
#  'query_5': {'user_input': 'a spanner symbol appeared on my display',
#   'category': 'icon',
#   'relevant_pages': [57],
#   'enriched_query': 'a spanner symbol appeared on my display scheduled servicing',
#   'triggered': ['spanner'],
#   'latency': {'query_enrichment': 0.00010377699982200284,
#    'raw_retrieval': 0.017920041999786918,
#    'raw_generation': 2.3672627390001253,
#    'enriched_retrieval': 0.02233454100041854,
#    'enriched_generation': 4.0188053809997655,
#    'reranking': 0.04157250299977022,
#    'reranked_generation': 12.821999761999905},
#   'raw': {'retrieved_pages': [57, 44, 78, 57, 104],
#    'answer': 'I could not find information about a spanner symbol in the manual. [Page]'},
#   'enriched': {'retrieved_pages': [113, 57, 44, 113, 57],
#    'answer': 'I could not find this in the manual [Page 113] regarding a spanner symbol appearing in the scheduled servicing context.'},
#   'reranked': {'retrieved_pages': [57, 113, 114, 120, 113],
#    'rerank_scores': [3.166, -2.214, -4.833, -4.839, -5.786],
#    'answer': 'According to the manual [Chunk 1, Page 57], when the next scheduled service is approaching, the symbol "Service" appears on the display. This indicates that it is time for a scheduled service based on either distance or time, as outlined in the Scheduled Servicing Plan [Chunks 3 and 4, Pages 113-120]. To ensure the longevity of your vehicle, it is essential to follow the instructions in the Scheduled Servicing Plan, including regularly checking fluid levels and tyre pressure [Chunk 5, Page 113].'}},
#  'query_6': {'user_input': 'check engine light came on',
#   'category': 'icon',
#   'relevant_pages': [49],
#   'enriched_query': 'check engine light came on injection eobd system failure',
#   'triggered': ['check engine light', 'engine light'],
#   'latency': {'query_enrichment': 0.00012294499993004138,
#    'raw_retrieval': 0.03087755200022002,
#    'raw_generation': 36.45474009999998,
#    'enriched_retrieval': 0.020090371000151208,
#    'enriched_generation': 24.410791214000255,
#    'reranking': 0.03573783199999525,
#    'reranked_generation': 25.847756175000086},
#   'raw': {'retrieved_pages': [62, 46, 44, 49, 46],
#    'answer': 'Based on the provided manual excerpts, the check engine light coming on could be due to several reasons. It could be caused by an issue with the engine coolant temperature being too high [Chunk 2, Page 46], insufficient engine oil/pressure [Chunk 3, Page 44], or a failure in the injection/EOBD system [Chunk 4, Page 49]. The light may switch on and off intermittently or stay on constantly. If the coolant temperature is too high, the warning light should switch off after a few seconds once the engine has been restarted and the coolant level checked. If the engine oil pressure is insufficient, the warning light should switch off as soon as the engine is started. However, if the injection/EOBD system is failing, the warning light may stay on or come on while driving, indicating possible loss of performance, high exhaust emissions, poor driveability, and high fuel consumption levels. [Chunk 4, Page 49] If the car is used under demanding conditions, it may be necessary to slow down and wait for a few minutes with the engine running to further favour the coolant circulation. [Chunk 5, Page 46]\n\nI could not find any information in the manual regarding the check engine light flashing for about 1 second and then going off. This issue may require further investigation beyond the provided manual excerpts.'},
#   'enriched': {'retrieved_pages': [49, 54, 49, 81, 43],
#    'answer': 'According to the manual [Chunk 1, Page 49], if the engine light (ICON: Injection/eobd system failure light) comes on, it indicates that the injection system is not working correctly, causing possible loss of performance, high exhaust emissions, poor driveability and high fuel consumption levels. The manual advises to contact a Fiat Dealership as soon as possible [Chunk 1, Page 49]. Additionally, the manual [Chunk 2, Page 54] warns that the presence of water in the supply circuit may damage the injection system and cause irregular engine operation. If the warning light comes on immediately after refueling, water may have entered the tank and should be addressed promptly. [Chunk 3, Page 49] also mentions that the warning light may come on along with a message on the display, in which case a Fiat Dealership should be contacted. Therefore, based on the information provided in the manual, it is recommended to contact a Fiat Dealership to have the injection system checked as soon as possible. [Page 49, 54]'},
#   'reranked': {'retrieved_pages': [49, 49, 81, 43, 54],
#    'rerank_scores': [7.596, 6.415, 6.227, 2.665, 2.449],
#    'answer': 'According to the manual [Chunk 1, Page 49], if the check engine light (ICON: Injection/eobd system failure light, engine light) comes on, it indicates that the injection/eobd system is not working correctly, which may cause loss of performance, high exhaust emissions, poor driveability, and high fuel consumption levels. The manual advises contacting a Fiat Dealership as soon as possible [Chunk 2, Page 49].\n\nSources:\n- Chunk 1: Page 49\n- Chunk 2: Page 49\n- Chunk 3: Page 81\n- Chunk 4: Page 43\n- Chunk 5: Page 54\n\n[Page 49, Chunk 1 and 2]\n\nAnswer: The check engine light (ICON: Injection/eobd system failure light, engine light) coming on indicates an issue with the injection/eobd system. The manual advises contacting a Fiat Dealership as soon as possible [Chunk 2, Page 49].'}},
#  'query_7': {'user_input': "there's a snowflake light on",
#   'category': 'icon',
#   'relevant_pages': [57],
#   'enriched_query': "there's a snowflake light on possible ice on road light",
#   'triggered': ['snowflake'],
#   'latency': {'query_enrichment': 0.00011583500008782721,
#    'raw_retrieval': 0.020642843000132416,
#    'raw_generation': 5.229155202000129,
#    'enriched_retrieval': 0.01808882299974357,
#    'enriched_generation': 14.656321354999818,
#    'reranking': 0.034855507999964175,
#    'reranked_generation': 5.105388276999747},
#   'raw': {'retrieved_pages': [57, 52, 78, 52, 55],
#    'answer': 'According to the manual [Chunk 1, Page 57], the snowflake light comes on when the outside temperature falls below 3°C, warning the driver of the possible presence of ice on the road.'},
#   'enriched': {'retrieved_pages': [57, 57, 52, 78, 93],
#    'answer': 'According to the manual [Chunk 1 | Page 57], the snowflake light is displayed when the outside temperature falls below 3°C. This warning is intended to alert the driver of the possible presence of ice on the road. No action is required from the driver, but they should exercise caution while driving in such conditions.\n\nIf the light does not go off after some time, it could indicate a malfunction in the temperature sensor. In this case, contact a Fiat Dealership for further assistance [Chunk 3 | Page 52].\n\nI could not find any information in the manual regarding replacing the possible ice on road light bulb.'},
#   'reranked': {'retrieved_pages': [57, 57, 39, 78, 52],
#    'rerank_scores': [5.022, 2.637, -0.022, -7.318, -7.713],
#    'answer': 'The snowflake light is a warning that the outside temperature has fallen below 3°C and may indicate the possible presence of ice on the road [Page 57].'}},
#  'query_8': {'user_input': 'I see a light with ABS written on it',
#   'category': 'icon',
#   'relevant_pages': [48, 59],
#   'enriched_query': 'i see a light with abs written on it abs failure light',
#   'triggered': ['abs written'],
#   'latency': {'query_enrichment': 0.00010470200004419894,
#    'raw_retrieval': 0.02767930099980731,
#    'raw_generation': 5.958836042000257,
#    'enriched_retrieval': 0.020065138000063598,
#    'enriched_generation': 11.163582936000239,
#    'reranking': 0.037068911000005755,
#    'reranked_generation': 5.457089380999605},
#   'raw': {'retrieved_pages': [48, 48, 78, 50, 51],
#    'answer': 'According to the manual [Page 48], the ABS failure light comes on when the system is inefficient but the braking system maintains its efficiency without the advantage of the ABS system. Drive carefully and contact a Fiat Dealership as soon as possible.'},
#   'enriched': {'retrieved_pages': [48, 48, 59, 182, 60],
#    'answer': 'According to the manual [Page 48], the ABS failure light comes on when the system is inefficient. However, the system still maintains its efficiency without the advantage of the ABS system. The driver should drive carefully and contact a Fiat Dealership as soon as possible [57]. The manual also suggests that if the ABS intervenes, the driver should not be afraid to keep the pedal pushed down to help stop in the shortest distance possible [Page 60].'},
#   'reranked': {'retrieved_pages': [48, 48, 43, 182, 50],
#    'rerank_scores': [3.3, 2.49, -3.146, -3.366, -3.974],
#    'answer': 'According to the manual [Page 48], an ABS failure light comes on when the system is inefficient but the braking system maintains its efficiency. Drive carefully and contact a Fiat Dealership as soon as possible.'}},
#  'query_9': {'user_input': "there's a little car with a padlock symbol",
#   'category': 'icon',
#   'relevant_pages': [50],
#   'enriched_query': "there's a little car with a padlock symbol fiat code system failure light",
#   'triggered': ['car with a padlock symbol'],
#   'latency': {'query_enrichment': 0.00011258299991823151,
#    'raw_retrieval': 0.030736170999716705,
#    'raw_generation': 10.517508295000425,
#    'enriched_retrieval': 0.020207996999943134,
#    'enriched_generation': 4.0012060989997735,
#    'reranking': 0.04295977599986145,
#    'reranked_generation': 4.436530122000022},
#   'raw': {'retrieved_pages': [42, 13, 14, 57, 69],
#    'answer': "Based on the provided manual excerpts, the padlock symbol could refer to the Dead Lock feature [Page 42] or the Rear Door Emergency Locking Device [Page 14]. Both features prevent the doors from being opened from the inside. However, without more specific information, it is impossible to determine which one is activated in the car in question.\n\n[Source: Fiat Punto II Owner's Manual]"},
#   'enriched': {'retrieved_pages': [50, 12, 50, 57, 49],
#    'answer': 'The warning light indicates a Fiat Code System failure. Contact a Fiat Dealership as soon as possible [Page 50].'},
#   'reranked': {'retrieved_pages': [50, 50, 57, 43, 4],
#    'rerank_scores': [2.189, 2.057, 1.812, 1.705, 1.689],
#    'answer': 'The warning light indicates a Fiat CODE system failure. Contact a Fiat Dealership as soon as possible. [Page 50]'}},
#  'query_10': {'user_input': 'seatbelt light is on',
#   'category': 'icon',
#   'relevant_pages': [41],
#   'enriched_query': 'seatbelt light is on seat belts not fastened light',
#   'triggered': ['seatbelt'],
#   'latency': {'query_enrichment': 0.00010010699998019845,
#    'raw_retrieval': 0.019969489999766665,
#    'raw_generation': 16.369438183000057,
#    'enriched_retrieval': 0.019307488999857014,
#    'enriched_generation': 16.87313103600036,
#    'reranking': 0.04840456700003415,
#    'reranked_generation': 16.328017686000294},
#   'raw': {'retrieved_pages': [41, 52, 75, 56, 75],
#    'answer': 'According to the manual [Page 41], a seatbelt light is a less serious fault indicated by a warning "cycle" with a shorter duration. To confirm the seatbelt activation/deactivation, follow the instructions on [Page 75]. Press the MENU/ button, then the [ICON: Seat belts not fastened light] button, and use the + and – buttons to select "Yes" or "No" to confirm the activation/deactivation. Briefly press the MENU/ button again to confirm the selection. If the seatbelt light remains on after following these steps, it may be necessary to contact a Fiat Dealership [Page 41].'},
#   'enriched': {'retrieved_pages': [75, 41, 41, 64, 75],
#    'answer': 'According to the manual [Chunk 2, Page 41], the seat belt light comes on when the seat belts are not fastened. To deactivate the buzzer permanently, contact a Fiat Dealership. However, if the light is flashing, it may indicate a less serious fault that can be interrupted by pressing the MENU/ button [Chunk 3, Page 41]. If the customer wants to reactivate the system, they can do so through the Setup Menu on vehicles with a multifunction display [Chunk 4, Page 64]. To confirm activation or deactivation, press the + or – buttons and select "Yes" or "No" [Chunk 5, Page 75].'},
#   'reranked': {'retrieved_pages': [41, 64, 75, 75, 41],
#    'rerank_scores': [8.025, 7.422, 6.883, 6.591, 6.428],
#    'answer': 'The seatbelt light is a warning that indicates one or both of the front seat belts are not fastened. To deactivate the acoustic warning permanently, contact a Fiat Dealership [Page 41, 64]. With some versions, the system can be reactivated from the Setup Menu [Page 64, 75]. To reactivate the system through the display Setup Menu, press the MENU/ button, select "Yes" to confirm activation/deactivation, and briefly press the MENU/ button again [Page 75]. If the light is on due to a fault, it will stay on until the cause is eliminated [Page 41].'}},
#  'query_11': {'user_input': "my car won't start",
#   'category': 'symptom',
#   'relevant_pages': [81, 12, 4, 108],
#   'enriched_query': "my car won't start engine starting failure",
#   'triggered': ["won't start"],
#   'latency': {'query_enrichment': 0.00010187599991695606,
#    'raw_retrieval': 0.029342324000026565,
#    'raw_generation': 21.095502333999775,
#    'enriched_retrieval': 0.018023229999926116,
#    'enriched_generation': 15.199929628000064,
#    'reranking': 0.031225627999901917,
#    'reranked_generation': 18.541992961999767},
#   'raw': {'retrieved_pages': [12, 101, 81, 110, 81],
#    'answer': "Based on the provided manual excerpts, if the car won't start, the technician should first try turning the key to STOP and then to MAR [Chunk 1, Page 12]. If the issue persists, they should check the electric window motor on the driver-side front door, electric door mirror movement, rain sensor, sunroof control unit, and My Port infotelematic system socket [Chunk 2, Page 101]. If the lights stay on even after retrying with the other keys, the technician should contact a Fiat Dealership [Chunk 1, Page 12 and Chunk 3, Page 81]. It is also important to note that the engine should not be started while being towed [Chunk 4, Page 110]. If the glow plug heating or injection/eobd system failure light is on, the technician should follow the instructions in the manual for those specific issues [Chunk 5, Page 81]."},
#   'enriched': {'retrieved_pages': [81, 7, 49, 81, 108],
#    'answer': 'If the engine does not start at the first attempt, return the ignition key to STOP before repeating the procedure [Page 81]. If the warning lights (petrol and Diesel versions) stay on in the instrument panel, bring the ignition key back to STOP and then to MAR again [Page 81]. If the engine still does not start, contact a Fiat Dealership [Page 81]. Do not leave the ignition key at MAR when the engine is stopped [Page 81]. If the engine fails to start due to a drained battery, any accessories connected to the vehicle power sockets may have contributed to the issue [Page 108].'},
#   'reranked': {'retrieved_pages': [81, 81, 12, 108, 110],
#    'rerank_scores': [4.414, 2.091, 1.991, 1.76, -0.021],
#    'answer': 'Based on the provided manual excerpts, if the engine does not start at the first attempt, the ignition key should be returned to the STOP position before attempting to start again [Page 81]. If the warning lights remain on after trying with different keys, contact a Fiat Dealership [Page 81]. Additionally, any accessories connected to the vehicle power sockets can drain the battery if left connected for too long with the engine off [Page 108]. Therefore, it is recommended to unplug any accessories before attempting to start the engine. If the car is being towed, the engine should not be started [Page 110]. I could not find specific information in the manual regarding a glow plug heating failure or a failure to start due to a drained battery caused by the glow plugs.'}},
#  'query_12': {'user_input': 'the car is getting hot',
#   'category': 'symptom',
#   'relevant_pages': [46],
#   'enriched_query': 'the car is getting hot engine coolant temperature',
#   'triggered': ['getting hot'],
#   'latency': {'query_enrichment': 0.00010753200012914021,
#    'raw_retrieval': 0.025812740000219492,
#    'raw_generation': 18.995953944999656,
#    'enriched_retrieval': 0.022506194000015967,
#    'enriched_generation': 17.90960787300037,
#    'reranking': 0.03538461500011181,
#    'reranked_generation': 14.865882994000003},
#   'raw': {'retrieved_pages': [46, 128, 174, 5, 24],
#    'answer': 'Check the engine coolant temperature [Chunk 1, Page 46]. If the coolant level in the reservoir is below the MIN mark, wait for the engine to cool down and refill the coolant. If the coolant level is correct, the heater may be on [Chunk 5, Page 24]. In cold weather conditions, the heater switches on automatically to ensure faster passenger compartment warming. If the heater is not required, it will switch off automatically when the comfort conditions are reached. If the car is still getting hot, there might be an issue with the cooling system. I could not find information about windscreen washer fluid or the glove compartment in the manual excerpts provided. [Page 46, 128, 174, 24]'},
#   'enriched': {'retrieved_pages': [46, 46, 46, 172, 25],
#    'answer': 'Check the coolant level in the reservoir [Page 46]. If the level is below the MIN mark, top up with coolant and check that the level is between the MIN and MAX marks on the reservoir itself [Page 46]. If the warning light comes on again after restarting, contact a Fiat Dealership [Page 46]. If the car is used under demanding conditions, wait for 2 or 3 minutes with the engine running and slightly accelerated to further favour the coolant circulation [Page 46]. Ensure the coolant used is compatible with the laws in force in the countries where the vehicle is sold, R134a or R1234yf [Page 172]. Use only the gas indicated on the dedicated plate in the engine compartment for charging [Page 25].'},
#   'reranked': {'retrieved_pages': [46, 46, 127, 172, 128],
#    'rerank_scores': [4.33, 0.726, -0.342, -1.551, -1.992],
#    'answer': 'Check the coolant level in the reservoir when the engine is cold. If it is below the MIN mark, add the described fluid up to the MAX mark. Do not remove the reservoir cap when the engine is hot [Page 46, 128]. If the coolant level is normal and the warning light is still on, check the engine for any leaks [Page 46]. If the engine is overheating, stop the car, switch off the engine and wait for it to cool down before checking the coolant level [Page 46]. Do not replace the coolant plug when the engine is hot [Page 128].'}},
#  'query_13': {'user_input': 'what does the hill holder system failure light mean',
#   'category': 'icon',
#   'relevant_pages': [50],
#   'enriched_query': 'what does the hill holder system failure light mean',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00012253299973963294,
#    'raw_retrieval': 0.033211551000022155,
#    'raw_generation': 13.518315421999887,
#    'enriched_retrieval': 0.02654155600021113,
#    'enriched_generation': 12.87466016999997,
#    'reranking': 0.04674846499983687,
#    'reranked_generation': 12.391619933000129},
#   'raw': {'retrieved_pages': [50, 50, 59, 60, 60],
#    'answer': 'The hill holder system failure light indicates a fault in the Hill Holder system, which is an integral part of the ESC system and facilitates starting on slopes [Chunk 3, Page 59]. If the light stays on instead of going off after a few seconds, contact a Fiat Dealership as soon as possible [Chunk 2, Page 50]. The Hill Holder system is not a parking brake and should not be relied upon to hold the vehicle in place without also engaging the handbrake and parking the vehicle in safe conditions [Chunk 4, Page 60].'},
#   'enriched': {'retrieved_pages': [50, 50, 59, 60, 60],
#    'answer': 'The hill holder system failure light indicates a fault in the Hill Holder system, which is an integral part of the ESC system and facilitates starting on slopes [Chunk 3, Page 59]. If the light stays on instead of going off after a few seconds, contact a Fiat Dealership as soon as possible [Chunk 2, Page 50]. The Hill Holder system is not a parking brake and should not be relied upon to hold the vehicle in place without also engaging the handbrake and parking the vehicle in safe conditions [Chunk 4, Page 60].'},
#   'reranked': {'retrieved_pages': [50, 50, 59, 50, 60],
#    'rerank_scores': [7.511, 6.531, 2.93, 2.478, 1.688],
#    'answer': 'The hill holder system failure light comes on when there is a fault in the Hill Holder system. It should go off after a few seconds, but if it stays on, contact a Fiat Dealership [Page 50]. The Hill Holder system is an integral part of the ESC system and facilitates starting on slopes [Page 59]. It is not a parking brake, so always engage the handbrake and park the vehicle in safe conditions [Page 60].'}},
#  'query_14': {'user_input': 'I hear a grinding noise when I brake',
#   'category': 'symptom',
#   'relevant_pages': [53, 111],
#   'enriched_query': 'i hear a grinding noise when i brake brake pad wear',
#   'triggered': ['grinding'],
#   'latency': {'query_enrichment': 0.00011167399998157634,
#    'raw_retrieval': 0.021133020000434044,
#    'raw_generation': 2.9240319979999185,
#    'enriched_retrieval': 0.024306595000325615,
#    'enriched_generation': 21.764700481999625,
#    'reranking': 0.03555275400003666,
#    'reranked_generation': 12.244201618000261},
#   'raw': {'retrieved_pages': [61, 88, 48, 126, 60],
#    'answer': 'I could not find this issue mentioned in the manual excerpts provided.'},
#   'enriched': {'retrieved_pages': [122, 61, 116, 113, 53],
#    'answer': 'Check front disc brake pads for excessive wear [Page 122]. If the noise continues after pad replacement, inspect rear disc brake pads or drum brake linings [Page 116, 113]. [Page 53] The brake pad wear light may come on before the pads are completely worn. If the light is not on, and the noise is severe, there may be metal-on-metal contact, which could damage components. Inspect the pads and rotors carefully. If metal-on-metal contact is confirmed, replace the rotors as well. [Page 113] If the vehicle is used under certain conditions, more frequent brake pad inspections are required. [Page 61] The Mechanical Brake Assist system may produce noises when it intervenes. If the noise is not related to the brake system, it may be from this system. Keep the brake pedal pressed firmly while braking.'},
#   'reranked': {'retrieved_pages': [61, 60, 53, 122, 116],
#    'rerank_scores': [2.51, -1.647, -2.024, -3.682, -3.832],
#    'answer': 'According to the manual [Chunk 1 | Page 61], when the Mechanical Brake Assist intervenes, noises may be heard from the system. However, if the noise is a grinding noise and the brake pads are worn, as indicated by the warning light [ICON: Brake pad wear light] on [Chunk 3 | Page 53], then the pads should be changed as soon as possible [Chunk 3 | Page 53]. Therefore, the cause of the noise is likely worn brake pads.'}},
#  'query_15': {'user_input': 'I have a flat tyre',
#   'category': 'symptom',
#   'relevant_pages': [55, 106],
#   'enriched_query': 'i have a flat tyre tyre pressure tyre',
#   'triggered': ['flat tyre'],
#   'latency': {'query_enrichment': 0.00010277600040353718,
#    'raw_retrieval': 0.030124381999939942,
#    'raw_generation': 21.820050417000402,
#    'enriched_retrieval': 0.017439165999803663,
#    'enriched_generation': 21.568656423999983,
#    'reranking': 0.039933528000346996,
#    'reranked_generation': 22.54458471099997},
#   'raw': {'retrieved_pages': [106, 106, 61, 91, 55],
#    'answer': 'According to the manual [Chunk 1, Page 106], if the tyre is punctured on the side or the vehicle has been driven with a flat tyre, the quick tyre repair kit cannot be used. Instead, the driver should stop the vehicle, check the tyre pressure after driving for about 10 minutes [Chunk 2, Page 106], and if the pressure is at least 1.8 bar, restore the correct pressure and drive carefully to the nearest Fiat Dealership [Chunk 2, Page 106]. If the vehicle is equipped with the iTPMS system [Chunk 3, Page 61], the system will indicate a low tyre pressure and the driver should restore the correct pressure value. In case of emergency, the driver can call the freephone number found in the Warranty Booklet or the national or international universal freephone number to search for the nearest Dealership [Chunk 4, Page 91].'},
#   'enriched': {'retrieved_pages': [105, 55, 106, 106, 139],
#    'answer': 'Refer to the "Technical specifications" section on Page 105 for the recommended tyre pressure. Use a tyre gauge to check the pressure and inflate to the specified value if necessary. If the tyre cannot be inflated to the recommended pressure, move the vehicle a short distance to redistribute the sealing fluid inside the tyre and try again. Do not use the quick tyre repair kit on punctures on the side of the tyre or on tyres damaged by running with a flat tyre [Page 105, 106]. If the tyre is beyond repair, use the space saver spare wheel listed on Page 139.'},
#   'reranked': {'retrieved_pages': [55, 61, 140, 62, 62],
#    'rerank_scores': [4.334, 3.781, 1.694, 0.292, -0.577],
#    'answer': 'Based on the provided manual excerpts, the warning light for a flat tyre in the iTPMS system (indirect Tire Pressure Monitoring System) comes on constantly to indicate that the tyre pressure is lower than the recommended value [Chunk 1, Page 55]. It is recommended to restore the correct pressure value [Chunk 1, Page 55]. The tyre pressure should be checked with tyres cold [Chunk 3, Page 140], and the inflation pressure should be + 0.1 bar with respect to the prescribed figure for the iTPMS [Chunk 3, Page 140]. The system cannot indicate sudden tyre pressure drops or inflate the tyres [Chunk 5, Page 62]. Insufficient tyre inflation increases fuel consumption, reduces the tread duration, and may affect the capacity to drive safely [Chunk 5, Page 62].\n\n[Source: Manual excerpts provided]'}},
#  'query_16': {'user_input': 'why does the engine lose power while driving',
#   'category': 'symptom',
#   'relevant_pages': [49],
#   'enriched_query': 'why does the engine lose power while driving',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00011723800025720266,
#    'raw_retrieval': 0.02074468099999649,
#    'raw_generation': 1.840112506999958,
#    'enriched_retrieval': 0.021079013999951712,
#    'enriched_generation': 2.000496656999985,
#    'reranking': 0.03610259800007043,
#    'reranked_generation': 22.61852656500014},
#   'raw': {'retrieved_pages': [108, 44, 62, 50, 28],
#    'answer': 'I could not find this in the manual.'},
#   'enriched': {'retrieved_pages': [108, 44, 62, 50, 28],
#    'answer': 'I could not find this in the manual.'},
#   'reranked': {'retrieved_pages': [108, 44, 28, 109, 110],
#    'rerank_scores': [-0.277, -2.197, -3.636, -4.24, -4.391],
#    'answer': 'I could not find this in the manual.'}},
#  'query_17': {'user_input': 'engine keeps cutting out',
#   'category': 'symptom',
#   'relevant_pages': [49, 81],
#   'enriched_query': 'engine keeps cutting out engine stalling ignition malfunction Fuel cut-off',
#   'triggered': ['cutting out'],
#   'latency': {'query_enrichment': 0.00010144699990632944,
#    'raw_retrieval': 0.017819318999954703,
#    'raw_generation': 30.855552107999756,
#    'enriched_retrieval': 0.02001530699999421,
#    'enriched_generation': 12.211688976999994,
#    'reranking': 0.037047960000109015,
#    'reranked_generation': 18.204822656000033},
#   'raw': {'retrieved_pages': [109, 116, 29, 49, 62],
#    'answer': 'Based on the information provided in the manual excerpts, the issue of the engine cutting out could be related to the fuel cut-off system [Page 109]. If the fuel supply is being interrupted, the engine may cut out. However, it is important to note that the manual does not provide specific information on how to diagnose or repair this issue. It only mentions that the fuel cut-off system intervenes in the case of an impact causing the interruption of the fuel supply. Therefore, further investigation and diagnosis would be required using additional tools and resources beyond the information provided in the manual.'},
#   'enriched': {'retrieved_pages': [109, 109, 149, 49, 109],
#    'answer': 'Check for fuel leaks [Page 109]. Turn ignition key to MAR [Page 109]. For LPG versions, check LPG safety valves [Page 109]. For Natural Power versions, check power supply [Page 109]. If an injection/eobd system failure is indicated [Page 49], contact a Fiat Dealership.\n\nI could not find information about the cause of the ignition malfunction in the provided manual excerpts.'},
#   'reranked': {'retrieved_pages': [109, 109, 85, 109, 29],
#    'rerank_scores': [3.874, 1.266, -2.171, -3.26, -5.058],
#    'answer': 'Based on the provided manual excerpts, if the engine keeps cutting out or stalling and is suspected to be an ignition malfunction, the fuel cut-off system may be intervening. This system is designed to interrupt the fuel supply in the event of an impact [Chunk 1 | Page 109]. However, if the engine is not involved in an impact, the fuel cut-off system should not be cutting off the fuel supply. To restore the correct operation of the vehicle, the technician should turn the ignition key to the MAR position [Chunk 4 | Page 109]. If the problem persists, further investigation is required. I could not find information in the manual regarding an ignition malfunction specifically causing the fuel cut-off system to activate.'}},
#  'query_18': {'user_input': "I think I'm using too much fuel",
#   'category': 'symptom',
#   'relevant_pages': [49, 153],
#   'enriched_query': "i think i'm using too much fuel fuel consumption",
#   'triggered': ['using too much fuel'],
#   'latency': {'query_enrichment': 0.00022548299966729246,
#    'raw_retrieval': 0.03171464500019283,
#    'raw_generation': 11.657081194000057,
#    'enriched_retrieval': 0.04062776599994322,
#    'enriched_generation': 18.370441117000155,
#    'reranking': 0.04804841499981194,
#    'reranked_generation': 17.497745619999932},
#   'raw': {'retrieved_pages': [4, 46, 153, 108, 109],
#    'answer': 'According to the manual [Page 153], various factors such as driving style, traffic conditions, weather conditions, car load, and use of climate control system can affect fuel consumption. The fuel consumption will become more regular after driving the first 3000 km. Additionally, [Page 108] mentions that accessories connected to the vehicle power sockets draw current even when not in use, which can cause the battery to drain and potentially prevent the engine from starting. However, I could not find specific information in the manual regarding fuel efficiency or fuel consumption rates.'},
#   'enriched': {'retrieved_pages': [153, 153, 153, 144, 127],
#    'answer': 'According to the manual [Chunk 1, Page 153], fuel consumption can vary depending on several factors such as driving style, condition of the car, use of climate control system, car load, presence of roof racks and other situations that adversely affect the aerodynamics or wind resistance. The fuel consumption will get more regular only after having driven the first 3000 km. The fuel consumption figures given in the manual [Chunk 3, Page 153] are determined on the basis of type-approval tests. If the fuel consumption is still high after considering these factors and driving the vehicle for a significant distance, it would be recommended to have the vehicle inspected by a qualified technician. I could not find specific information in the manual regarding maximum fuel consumption or fuel consumption checks.'},
#   'reranked': {'retrieved_pages': [153, 153, 153, 127, 82],
#    'rerank_scores': [-5.52, -6.304, -6.815, -7.331, -8.722],
#    'answer': 'According to the manual [Page 153], the fuel consumption figures given are based on type-approval tests. Various factors such as driving style, condition of the car, and weather conditions can affect the actual fuel consumption. The fuel consumption will become more regular after the first 3000 km [Page 153]. The maximum engine oil consumption is usually 400 grams every 1000 km [Page 127], but the engine oil consumption conditions should be considered as having stabilized after the first 5000-6000 km [Page 127]. It is advisable not to demand maximum performance from the vehicle during the initial period of use [Page 82]. I could not find specific information about fuel consumption issues in the manual.'}},
#  'query_19': {'user_input': "there's smoke coming from the engine",
#   'category': 'symptom',
#   'relevant_pages': [46],
#   'enriched_query': "there's smoke coming from the engine engine smoke overheating cooling emergency",
#   'triggered': ['smoke'],
#   'latency': {'query_enrichment': 0.0001036740000017744,
#    'raw_retrieval': 0.021706440999878396,
#    'raw_generation': 15.4523637530001,
#    'enriched_retrieval': 0.018775866999931168,
#    'enriched_generation': 19.02262913000004,
#    'reranking': 0.04968909600029292,
#    'reranked_generation': 18.375990364000245},
#   'raw': {'retrieved_pages': [127, 81, 90, 133, 109],
#    'answer': 'According to Chunk 1 [Page 127], there is a risk of fire when working in the engine compartment and gas or inflammable vapours may be present. In Chunk 5 [Page 109], it is warned that if you smell fuel or notice leaks from the fuel system, do not reactivate the system to avoid the risk of fire. Since the question states that there is smoke coming from the engine, it is recommended to follow the instructions in Chunk 5 and not reactivate the engine to avoid the risk of fire.\n\nCitation: Chunk 1 [Page 127], Chunk 5 [Page 109]'},
#   'enriched': {'retrieved_pages': [127, 46, 133, 46, 90],
#    'answer': 'I could not find specific instructions regarding engine smoke or overheating in the provided manual excerpts. However, according to Chunk 1 [Page 127], it is important to never smoke while working in the engine compartment due to the risk of fire. If the smoke is coming from the engine while it is running, it is recommended to stop the engine, check the coolant level as described in Chunk 2 [Page 46], and wait for the engine to cool down before opening the cap. [Page 46] also suggests checking the coolant level on some versions when the warning light comes on. If the smoke is not coming from the engine but is a result of refueling with LPG, refer to Chunk 5 [Page 90] for instructions on refueling safely.'},
#   'reranked': {'retrieved_pages': [127, 46, 128, 46, 90],
#    'rerank_scores': [0.927, -1.935, -5.633, -6.367, -7.127],
#    'answer': 'Based on the provided excerpts, the warning light "engine coolant temperature too high" [Chunk 2, Page 46] comes on when the engine has overheated. The manual advises to stop the car, switch off the engine, and check the coolant level in the reservoir [Chunk 2, Page 46]. It is important to wait for the engine to cool down before checking the coolant level to avoid getting scalded [Chunk 3, Page 128]. The manual also warns against smoking in the engine compartment due to the presence of gas and inflammable vapors [Chunk 1, Page 127]. However, the manual does not provide information on what to do if there is smoke coming from the engine while it is overheating. I could not find this in the manual.'}},
#  'query_20': {'user_input': 'what does the ABS failure light mean',
#   'category': 'technical',
#   'relevant_pages': [48, 59, 60],
#   'enriched_query': 'what does the abs failure light mean',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00010635199987518718,
#    'raw_retrieval': 0.0217944789997091,
#    'raw_generation': 5.503652106000118,
#    'enriched_retrieval': 0.02353748599989558,
#    'enriched_generation': 5.74151863499992,
#    'reranking': 0.031936706000124104,
#    'reranked_generation': 5.557698634999724},
#   'raw': {'retrieved_pages': [48, 48, 51, 52, 59],
#    'answer': 'The ABS failure light means that the ABS system is inefficient, but the braking system maintains its efficiency without the advantage of the ABS system. Drive carefully and contact a Fiat Dealership as soon as possible. [Page 48]'},
#   'enriched': {'retrieved_pages': [48, 48, 51, 52, 59],
#    'answer': 'The ABS failure light comes on when the system is inefficient, but the braking system maintains its efficiency unaltered. Drive carefully and contact a Fiat Dealership as soon as possible. [Page 48]'},
#   'reranked': {'retrieved_pages': [48, 48, 50, 50, 43],
#    'rerank_scores': [5.503, 4.705, 2.586, 2.101, 1.974],
#    'answer': 'The ABS failure light comes on when the ignition key is turned to MAR and should switch off after a few seconds. If it does not go off or stays on while driving, contact a Fiat Dealership. [Page 48]'}},
#  'query_21': {'user_input': 'engine coolant temperature warning',
#   'category': 'technical',
#   'relevant_pages': [46],
#   'enriched_query': 'engine coolant temperature warning',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00011494799991851323,
#    'raw_retrieval': 0.021166343999993842,
#    'raw_generation': 15.787314123000215,
#    'enriched_retrieval': 0.024249599000086164,
#    'enriched_generation': 16.474839443999826,
#    'reranking': 0.033026805999725184,
#    'reranked_generation': 7.908799664000071},
#   'raw': {'retrieved_pages': [46, 46, 172, 34, 46],
#    'answer': 'The engine coolant temperature warning light comes on when the engine has overheated [Page 46]. In normal driving conditions, the warning light should switch off after a few seconds [Page 46]. If the warning light stays on, the engine may be overheating and the coolant level in the reservoir should be checked [Page 46]. The coolant level should be between the MIN and MAX marks on the reservoir [Page 46]. If the warning light comes on again after topping up the coolant, contact a Fiat Dealership [Page 46]. If the car is used under demanding conditions, the engine should be slowed down and the coolant circulation favoured [Page 46].'},
#   'enriched': {'retrieved_pages': [46, 46, 172, 34, 46],
#    'answer': 'The engine coolant temperature warning light comes on when the engine has overheated [Page 46]. In normal driving conditions, the warning light should switch off after a few seconds [Page 46]. If the warning light stays on, the engine may be overheating and the coolant level in the reservoir should be checked [Page 46]. The coolant level should be between the MIN and MAX marks on the reservoir [Page 46]. If the warning light comes on again after topping up the coolant, contact a Fiat Dealership [Page 46]. If the car is used under demanding conditions, the engine should be slowed down and the coolant circulation favoured [Page 46].'},
#   'reranked': {'retrieved_pages': [46, 37, 46, 172, 172],
#    'rerank_scores': [7.222, 6.019, 5.622, 5.513, 4.713],
#    'answer': 'According to the manual [Page 46], the engine coolant temperature warning light comes on when the engine has overheated. In a vehicle with a multifunction display [Page 172], this warning is indicated by the engine coolant temperature gauge with an overheating warning light [Fig. 2 or Fig. 3].'}},
# ...
#   'enriched': {'retrieved_pages': [129, 187, 22, 21, 21],
#    'answer': 'Check if the windscreen wipers are not lifted from the windscreen [Page 2]. If the wipers are in contact with the windscreen, try replacing the windscreen wiper blades [Page 129]. If the problem persists, contact a Fiat Dealership [Page 1].\n\nI could not find information in the manual about the cause of the windscreen wipers stopping in the provided context.'},
#   'reranked': {'retrieved_pages': [21, 22, 21, 21, 22],
#    'rerank_scores': [8.36, 5.283, 1.761, 1.154, 1.03],
#    'answer': 'According to the manual [Page 21], the windscreen wipers stop working three strokes after the stalk is released. If this is not the case, I could not find this in the manual. For further assistance, contact a Fiat Dealership.'}},
#  'query_45': {'user_input': 'how do I open the windows from inside the car?',
#   'category': 'component',
#   'relevant_pages': [25, 26],
#   'enriched_query': 'how do i open the windows from inside the car?',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00010570799986453494,
#    'raw_retrieval': 0.021989927000504395,
#    'raw_generation': 11.496558410999569,
#    'enriched_retrieval': 0.01802010000028531,
#    'enriched_generation': 11.304360398000426,
#    'reranking': 0.03193581899995479,
#    'reranked_generation': 7.459119426000143},
#   'raw': {'retrieved_pages': [30, 80, 26, 25, 29],
#    'answer': 'Press lever B fig. 33 inside the luggage compartment to open the tailgate, then completely fold down the rear seats. Once the rear seats are folded down, press button A fig. 23 or 24 on the door panel to open the windows from inside the car. [Page 80, 23, 24]\n\nI could not find information on opening windows from inside the car using the remote control in the provided excerpts.'},
#   'enriched': {'retrieved_pages': [30, 80, 26, 25, 29],
#    'answer': 'Press lever B fig. 33 inside the luggage compartment to open the tailgate, then completely fold down the rear seats. Once the rear seats are folded down, press button A fig. 23 or 24 on the door panel to open the windows from inside the car. [Page 80, 23, 24]\n\nI could not find information on opening windows from inside the car using the remote control in the provided excerpts.'},
#   'reranked': {'retrieved_pages': [26, 30, 25, 29, 13],
#    'rerank_scores': [3.679, 0.672, -0.304, -3.81, -4.481],
#    'answer': 'According to Chunk 1 [Page 26], the windows can be opened from the inside by completely folding down the rear seats and pressing lever B fig. 33 [Chunk 2 Page 30].\n\nI could not find information on opening windows from inside the car using the door controls in the provided manual excerpts.'}},
#  'query_46': {'user_input': 'how do I open the windows from outside the car?',
#   'category': 'component',
#   'relevant_pages': [26],
#   'enriched_query': 'how do i open the windows from outside the car?',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00010532499982218724,
#    'raw_retrieval': 0.019559480000680196,
#    'raw_generation': 8.723308028999782,
#    'enriched_retrieval': 0.019610786000157532,
#    'enriched_generation': 4.657192763999774,
#    'reranking': 0.042175932999271026,
#    'reranked_generation': 5.543306974999723},
#   'raw': {'retrieved_pages': [13, 30, 80, 26, 25],
#    'answer': 'Press button A fig. 24 on the door panel to open the front left window from outside the car [Page 24]. For other windows, refer to Chunk 4 [Page 26]. To open all windows at once using the remote control, press and hold the unlocking button on the key for more than 2 seconds [Page 26].'},
#   'enriched': {'retrieved_pages': [13, 30, 80, 26, 25],
#    'answer': 'Press button A fig. 32 on the tailgate [Page 13]. I could not find information on opening windows from outside the car in the provided excerpts for the driver side windows.'},
#   'reranked': {'retrieved_pages': [26, 30, 13, 25, 14],
#    'rerank_scores': [2.61, 1.592, 0.215, -1.018, -2.532],
#    'answer': 'Press button A on the tailgate [Chunk 2 | Page 30] or use the remote control to press the unlocking button for the windows [Chunk 1 | Page 26].'}},
#  'query_47': {'user_input': 'how do I refuel?',
#   'category': 'technical',
#   'relevant_pages': [90, 91],
#   'enriched_query': 'how do i refuel?',
#   'triggered': [],
#   'latency': {'query_enrichment': 8.799300030659651e-05,
#    'raw_retrieval': 0.018305043000509613,
#    'raw_generation': 7.857094328999665,
#    'enriched_retrieval': 0.020945498999935808,
#    'enriched_generation': 8.149696045999917,
#    'reranking': 0.035646927999550826,
#    'reranked_generation': 15.012744736000059},
#   'raw': {'retrieved_pages': [4, 80, 90, 7, 85],
#    'answer': 'To refuel, turn off the engine, engage the handbrake, turn the ignition key to the STOP position, open the access flap, undo the cap, and hand over the suitable filling adaptor to the LPG refuelling operators. Do not smoke during refuelling [Page 4, 80, 90].'},
#   'enriched': {'retrieved_pages': [4, 80, 90, 7, 85],
#    'answer': 'To refuel, turn off the engine, engage the handbrake, turn the ignition key to the STOP position, and hand over the suitable filling adaptor to the LPG refuelling operators. Open the access flap, undo the cap, and refuel [Page 4, 80, 90].'},
#   'reranked': {'retrieved_pages': [85, 90, 90, 90, 4],
#    'rerank_scores': [3.466, 1.286, 1.133, 0.867, -0.666],
#    'answer': 'To refuel, first ensure the engine is off and the ignition key is in the STOP position [Page 85, 90]. For LPG versions, follow the specific procedure: open flap A, secure cap B with the loss prevention strap, insert the dispenser, and refuel [Fig. 74, Page 90]. After refuelling, wait for at least 10 seconds before removing the dispenser and closing flap A [Fig. 74, Page 90]. Always use unleaded petrol with an octane number no lower than 95 for petrol engines [Page 4].'}},
#  'query_48': {'user_input': 'how do I change a tyre?',
#   'category': 'technical',
#   'relevant_pages': [103, 104],
#   'enriched_query': 'how do i change a tyre?',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00010373799977969611,
#    'raw_retrieval': 0.021287882999786234,
#    'raw_generation': 30.820591298999716,
#    'enriched_retrieval': 0.02109780199953093,
#    'enriched_generation': 26.900430683000195,
#    'reranking': 0.034070667999912985,
#    'reranked_generation': 25.353526293999494},
#   'raw': {'retrieved_pages': [105, 80, 106, 83, 106],
#    'answer': '1. Pull the handbrake. [Chunk 1, Page 105]\n2. Unscrew the tyre valve cap and take out the filler hose. [Chunk 3, Page 106]\n3. Tighten the ring nut on the tyre valve. [Chunk 3, Page 106]\n4. Start the engine and insert the compressor plug into a power socket. [Chunk 3, Page 106]\n5. Operate the compressor bringing switch to position I (on). [Chunk 3, Page 106]\n6. Depress the clutch pedal fully to change gear correctly. [Chunk 4, Page 83]\n7. Do not introduce tools between rim and tyre. [Chunk 1, Page 105]\n8. Check tyre and spare wheel pressure regularly. [Chunk 1, Page 105]\n9. Do not remove foreign bodies from the tyre. [Chunk 5, Page 106]\n10. Do not operate the compressor for longer than 20 consecutive minutes. [Chunk 5, Page 106]\n11. Tyres repaired with the quick tyre repair kit must only be used temporarily. [Chunk 5, Page 106]\n\n[Note: The manual'},
#   'enriched': {'retrieved_pages': [105, 80, 106, 83, 106],
#    'answer': '1. Pull the handbrake. [Chunk 1, Page 105]\n2. Unscrew the tyre valve cap and take out the filler hose. [Chunk 3, Page 106]\n3. Tighten the ring nut on the tyre valve. [Chunk 3, Page 106]\n4. Make sure compressor switch is in position 0 (off). [Chunk 3, Page 106]\n5. Start the engine and insert the compressor plug in the nearest power socket. [Chunk 3, Page 106]\n6. Operate the compressor bringing switch to position I (on). [Chunk 3, Page 106]\n7. Depress the clutch pedal fully to change gear correctly. [Chunk 4, Page 83]\n8. Do not remove foreign bodies from the tyre. [Chunk 3, Page 106]\n9. Do not operate the compressor for longer than 20 consecutive minutes. [Chunk 3, Page 106]\n\nI could not find information in the manual on how to physically remove the old tyre and mount the new one.'},
#   'reranked': {'retrieved_pages': [107, 106, 106, 105, 83],
#    'rerank_scores': [-0.536, -1.41, -2.659, -5.069, -5.748],
#    'answer': '1. Apply the handbrake [Page 105]\n2. Unscrew the tyre valve cap and attach the compressor plug to the nearest power socket [Page 106, F1E0139 and F1E0141]\n3. Operate the compressor bringing switch to position I (on) [Page 106, F1E0141]\n4. Check tyre pressure regularly [Page 105]\n5. Do not exceed 80 km/h, drive carefully and do not accelerate or brake suddenly if using a quick tyre repair kit [Page 107, 141-143]\n6. Do not attempt to repair a tyre with a damaged wheel rim [Page 106, 138]\n7. Do not introduce tools between the rim and tyre [Page 105, WARNING]\n8. Ensure the clutch pedal is fully depressed when changing gear [Page 83, WARNING and Page 105]'}},
#  'query_49': {'user_input': 'when should I check the car',
#   'category': 'technical',
#   'relevant_pages': [113],
#   'enriched_query': 'when should i check the car',
#   'triggered': [],
#   'latency': {'query_enrichment': 9.945999954652507e-05,
#    'raw_retrieval': 0.019470150000415742,
#    'raw_generation': 12.016120274000059,
#    'enriched_retrieval': 0.021037040000010165,
#    'enriched_generation': 30.43552428699968,
#    'reranking': 0.03301495600044291,
#    'reranked_generation': 17.33059832500021},
#   'raw': {'retrieved_pages': [113, 62, 114, 46, 88],
#    'answer': 'Every 1,000 km or before long journeys, check engine coolant level, brake fluid level, screen washer fluid level, tyre inflation pressure and condition, lighting system operation (headlights, direction indicators, hazard warning lights, etc.), screen washer/wiper system operation and positioning/wear of windscreen/ rear window wiper blades. Every 3,000 km, check and top up engine oil level. [Page 113]'},
#   'enriched': {'retrieved_pages': [113, 62, 114, 46, 88],
#    'answer': 'Every 1,000 km or before long journeys, check engine coolant level, brake fluid level, screen washer fluid level, tyre inflation pressure and condition, lighting system operation (headlights, direction indicators, hazard warning lights, etc.), screen washer/wiper system operation and positioning/wear of windscreen/ rear window wiper blades. Every 3,000 km, check and top up engine oil level [Page 113]. When the car is used under demanding conditions (e.g. towing trailers uphill or fully loaded), slow down and, if the warning light stays on, stop the car. Wait for 2 or 3 minutes with the engine running and slightly accelerated to further favour the coolant circulation [Page 46]. Check tyre condition/wear and adjust pressure, if necessary; check the expiry date of the “Fix&Go Automatic” repair kit (for versions/ markets, where provided) [Page 114, Year 1]. Check operation of lighting system (headlights, direction indicators, hazard warning lights, boot, passenger compartment, glove compartment, instrument panel warning lights, etc.) [Page 114, Year 2]. Check and top up fluid levels (engine oil, engine coolant, brake fluid, power steering fluid, transmission fluid, differential fluid, etc.) [Page'},
#   'reranked': {'retrieved_pages': [113, 113, 46, 62, 82],
#    'rerank_scores': [-0.043, -0.711, -0.936, -1.353, -3.133],
#    'answer': 'Every 1,000 km or before long journeys, check engine coolant level, brake fluid level, screen washer fluid level, tyre inflation pressure and condition, lighting system operation, screen washer/wiper system operation and positioning/wear of windscreen/ rear window wiper blades. Every 3,000 km, check and top up engine oil level [Page 113]. If the vehicle is used under demanding conditions (e.g. towing trailers uphill or fully loaded), check front disc brake pad condition and wear more often than indicated [Page 113]. After a demanding drive, allow the engine to idle before turning it off [Page 82].'}},
#  'query_50': {'user_input': 'there is a battery light on my dashboard',
#   'category': 'icon',
#   'relevant_pages': [44],
#   'enriched_query': 'there is a battery light on my dashboard',
#   'triggered': [],
#   'latency': {'query_enrichment': 0.00012221299948578235,
#    'raw_retrieval': 0.020990560999962327,
#    'raw_generation': 21.43052594599976,
#    'enriched_retrieval': 0.02019245600058639,
#    'enriched_generation': 21.19143331000032,
#    'reranking': 0.031712731999505195,
#    'reranked_generation': 29.287646843000402},
#   'raw': {'retrieved_pages': [44, 101, 48, 41, 99],
#    'answer': 'According to Chunk 1 [Page 44], a low battery charge warning light comes on when the ignition key is turned to MAR, but it should go out as soon as the engine has started. If the warning light stays on constantly or is flashing, contact a Fiat Dealership. Therefore, if the battery light is on while the engine is running, it could be a sign of a problem with the battery or charging system. To check the fuses related to the battery warning light, refer to Chunk 5 [Page 99] and the dashboard fuse box diagram. If the fuse is blown, replace it. If the fuse is fine, check the battery voltage with a multimeter. If the voltage is below 12.4V, the battery may be weak and need replacement. If the voltage is above 14.4V, there may be a problem with the charging system, such as a faulty alternator or voltage regulator.'},
#   'enriched': {'retrieved_pages': [44, 101, 48, 41, 99],
#    'answer': 'According to Chunk 1 [Page 44], a low battery charge warning light comes on when the ignition key is turned to MAR, but it should go out as soon as the engine has started. If the warning light stays on constantly or is flashing, contact a Fiat Dealership. Therefore, if the battery light is on while the engine is running, it could be a sign of a problem with the battery or charging system. To check the fuses related to the battery warning light, refer to Chunk 5 [Page 99] and the dashboard fuse box diagram. If the fuse is blown, replace it. If the fuse is fine, check the battery voltage with a multimeter. If the voltage is below 12.4V, the battery may be weak and need replacement. If the voltage is above 14.4V, there may be a problem with the charging system, such as a faulty alternator or voltage regulator.'},
#   'reranked': {'retrieved_pages': [44, 48, 101, 99, 53],
#    'rerank_scores': [-0.826, -0.879, -4.211, -7.959, -7.987],
#    'answer': 'According to the manual [Page 44], a low battery charge warning light comes on when the ignition key is turned to MAR but should go out as soon as the engine has started. If the warning light stays on constantly or is flashing, contact a Fiat Dealership. Therefore, if the battery light is on while the engine is running, it could be a sign of a problem with the charging system. However, it is important to note that the manual does not provide information on how to test the charging system or locate the cause of the problem. To diagnose and repair the issue, further investigation and specialized tools may be required. [I could not find this in the manual] To access the dashboard fuse box and check the battery fuse, refer to [Chunk 4 | Page 99] and [Chunk 3 | Page 101]. If the battery fuse is blown, it may indicate a problem with the charging system. However, a blown fuse may also be caused by a short circuit or other electrical issue. Therefore, it is important to use caution when working with electrical components and consult a qualified technician if necessary. [Chunk 1 | Page 44] states that if the warning light stays on constantly or flashes, contact a Fiat Dealership. It is recommended to follow this advice and have the issue diagnosed and repaired by a professional.'}}}
